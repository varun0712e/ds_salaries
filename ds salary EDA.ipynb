# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('ds_salaries.csv')

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# 3          Product Data Analyst   20000             USD          20000
# 4     Machine Learning Engineer  150000             USD         150000
# ..                          ...     ...             ...            ...
# 602               Data Engineer  154000             USD         154000
# 603               Data Engineer  126000             USD         126000
# 604                Data Analyst  129000             USD         129000
# 605                Data Analyst  150000             USD         150000
# 606                AI Scientist  200000             USD         200000
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0               DE            L
# 1                   JP             0               JP            S
# 2                   GB            50               GB            M
# 3                   HN             0               HN            S
# 4                   US            50               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
# [607 rows x 12 columns]

# %%
df['experience_level']=df['experience_level'].map({'EN':'Entry-level','MI':'Mid-level','SE':'Senior-level','EX':'Expert-level'})

# %%
df['experience_level']
# Out:
# 0         Mid-level
# 1      Senior-level
# 2      Senior-level
# 3         Mid-level
# 4      Senior-level
#            ...
# 602    Senior-level
# 603    Senior-level
# 604    Senior-level
# 605    Senior-level
# 606       Mid-level
# Name: experience_level, Length: 607, dtype: object

# %%
df.drop(['salary','salary_currency'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.countplot(df['work_year'])
plt.subplot(1,2,2)
plt.pie(df['work_year'].value_counts().values,labels=df['work_year'].value_counts().index,autopct='%1.2f%%')
plt.show()
# Out:
# C:\Users\Varun\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# More than half of the salary data is from 2022.
#
# Almost 1/3 of the data are from 2021
#
# Rest of the data are from 2020 with approximately 11.9% share.
#
# Possible Conclusion: Number of data science jobs are increasing over the years.

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.countplot(df['experience_level'])
plt.subplot(1,2,2)
plt.pie(df['experience_level'].value_counts().values,labels=df['experience_level'].value_counts().index,autopct='%1.2f%%')
plt.show()
# Out:
# C:\Users\Varun\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Number of senior-level employees are highest in the dataset.
#
# Also, the number of mid-level employees is quite close to senior-level.
#
# Meanwhile, the number of junior-level and expert-level employees is relatively low.

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.countplot(df['employment_type'])
plt.subplot(1,2,2)
plt.pie(df['employment_type'].value_counts().values,labels=df['employment_type'].value_counts().index,autopct='%1.2f%%')
plt.show()
# Out:
# C:\Users\Varun\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Number of full-time employees is significantly higher than others. Approximately 96.9% of the whole dataset.
#
# Number of part-time employees is very low.
#
# Meanwhile, the number of contract and freelance employees is almost next to zero.
#
# Possible Conclusion: Almost all the data science jobs require you to be a full-time employee.

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
# plt.figure(figsize=(16,8))
sns.countplot(df['job_title'], order=df['job_title'].value_counts(ascending=True).index)
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], label_type='edge', size=10, padding=1, fontname="Helvetica, Ariel", color="#7f7f7f")
plt.show()
# Out:
# C:\Users\Varun\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Number of Data Scientist and Data Engineer salary data are highest in the dataset.
#
# Data Analyst takes the third place.
#
# Machine Learning Engineer is the last significant title with approximately 40 entries.
#
# Possible Conclusion: Job market is mostly dominated by Data Scientists, Data Engineers, Data Analysts, and Machine Learning Engineers.

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.distplot(df['salary_in_usd'])
plt.subplot(1,2,2)
sns.boxplot(df['salary_in_usd'])
plt.show()
# Out:
# C:\Users\Varun\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Varun\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# By looking at the curve, we can say that most of the employees are getting paid around 1,00,000 USD.
#
# Higher salaries are quite rare, especially over 3,00,000 USD.

# %%
df[df['salary_in_usd']>300000].sort_values(by='salary_in_usd',ascending=False)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 252         252       2021     Expert-level              FT
# 33           33       2020        Mid-level              FT
# 97           97       2021        Mid-level              FT
# 157         157       2021        Mid-level              FT
# 225         225       2021     Expert-level              CT
# 63           63       2020     Senior-level              FT
# 523         523       2022     Senior-level              FT
# 519         519       2022     Senior-level              FT
# 25           25       2020     Expert-level              FT
# 482         482       2022     Expert-level              FT
#
#                               job_title  salary_in_usd employee_residence  \
# 252             Principal Data Engineer         600000                 US
# 33                   Research Scientist         450000                 US
# 97               Financial Data Analyst         450000                 US
# 157  Applied Machine Learning Scientist         423000                 US
# 225            Principal Data Scientist         416000                 US
# 63                       Data Scientist         412000                 US
# 523                 Data Analytics Lead         405000                 US
# 519              Applied Data Scientist         380000                 US
# 25             Director of Data Science         325000                 US
# 482                       Data Engineer         324000                 US
#
#      remote_ratio company_location company_size
# 252           100               US            L
# 33              0               US            M
# 97            100               US            L
# 157            50               US            L
# 225           100               US            S
# 63            100               US            L
# 523           100               US            L
# 519           100               US            L
# 25            100               US            L
# 482           100               US            M

# %% [markdown]
# They all live in the United States and work for US-based companies.
#
# 80% of them are working remote.
#
# Most of them are working at large companies.
#
# 90% of them are full-time employees.
#
# There are no junior-level employees who earn more than 300,000 USD.
#
# Possible Conclusion: If we get a data science job right now, we will most likely be paid around 100,000 USD. Only in the United States can we earn extremely high wages.

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
# plt.figure(figsize=(16,8))
sns.countplot(df['employee_residence'], order=df['employee_residence'].value_counts(ascending=True).index)
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], label_type='edge', size=10, padding=1, fontname="Helvetica, Ariel", color="#7f7f7f")
plt.show()
# Out:
# C:\Users\Varun\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The United States clearly dominates the competition with over 300 data entries.
#
# Great Britain, Canada, India, and Germany follows the United States, with less than 50 entries.
#
# Most of the countries are next to zero.
#
# Possible Conclusion: Data science jobs are much more popular and common in the United States than in any other country.

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.countplot(df['remote_ratio'])
plt.subplot(1,2,2)
plt.pie(df['remote_ratio'].value_counts().values,labels=df['remote_ratio'].value_counts().index,autopct='%1.2f%%')
plt.show()
# Out:
# C:\Users\Varun\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Remote jobs are more popular by far with approximately 62.8% share.
#
# Hybrid and On-site jobs almost have the same popularity.
#
# Possible Conclusion: This result may be due to the covid pandemic. It is known that remote jobs are increasing because of the pandemic.
#
# Later on, I will analyze the remote work ratio and work year at the same time to see if there is a correlation as I suspected.

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))
# plt.figure(figsize=(16,8))
sns.countplot(df['company_location'], order=df['company_location'].value_counts(ascending=True).index)
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], label_type='edge', size=10, padding=1, fontname="Helvetica, Ariel", color="#7f7f7f")
plt.show()
# Out:
# C:\Users\Varun\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The result is extremely similar to employee residence distribution.
#
# The United States dominates every other country by far.
#
# Great Britain, Canada, India, and Germany are following the United States.
#
# Possible Conclusion: Similar to employee residence analysis, most of the employers (companies) are US based.

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.countplot(df['company_size'],order=df['company_size'].value_counts(ascending=True).index)
plt.subplot(1,2,2)
plt.pie(df['company_size'].value_counts().values,labels=df['company_size'].value_counts().index,autopct='%1.2f%%')
plt.show()
# Out:
# C:\Users\Varun\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['company_size'].value_counts()
# Out:
# M    326
# L    198
# S     83
# Name: company_size, dtype: int64

# %% [markdown]
# Medium size companies take the lead with approximately 53.7% share.
#
# Almost 1/3 of the data science jobs are posted by Large size companies.
#
# Possible Conclusion: I assume that, in general, the number of large size companies is less than medium size companies. The difference in results between medium size and large size companies may be due to this reason. Meanwhile, small size companies may not require a data scientist or any data science-related employee.

# %%
from numpy import mean
fig, ax = plt.subplots(1, 1, figsize=(20, 7))

sns.barplot(x='work_year',y='salary_in_usd',data=df,estimator=mean)
ax.bar_label(ax.containers[0], label_type='edge', size=10, padding=1, fontname="Helvetica, Ariel", color="#7f7f7f")
plt.show()

# %%
diff_2022 = df.groupby("work_year")["salary_in_usd"].mean().loc[2022] - df.groupby("work_year")["salary_in_usd"].mean().loc[2021]
diff_2022_in_percentage = diff_2022 / df.groupby("work_year")["salary_in_usd"].mean().loc[2021] * 100 
print(f'2021-2022 average salary increase: {diff_2022_in_percentage:.2f}%')
# Out:
# 2021-2022 average salary increase: 24.70%

# %% [markdown]
# Salaries increased in 2021 but not that much.
#
# Salaries increased significantly in 2022 with approximately 24.70%.
#
# Possible Conclusion: Data science jobs are becoming more important; therefore, salaries are increasing over the years. This may be due to the fact that companies are learning what they can do with their data. For example; increasing efficiency, cutting costs, etc.

# %%
from numpy import mean
fig, ax = plt.subplots(1, 1, figsize=(20, 7))

sns.barplot(x='experience_level',y='salary_in_usd',data=df,estimator=mean)
ax.bar_label(ax.containers[0], label_type='edge', size=10, padding=1, fontname="Helvetica, Ariel", color="#7f7f7f")
plt.show()

# %%
diff_2022 = df.groupby("work_year")["salary_in_usd"].mean().loc[2022] - df.groupby("work_year")["salary_in_usd"].mean().loc[2021]
diff_2022_in_percentage = diff_2022 / df.groupby("work_year")["salary_in_usd"].mean().loc[2021] * 100 
print(f'2021-2022 average salary increase: {diff_2022_in_percentage:.2f}%')
# Out:
# 2021-2022 average salary increase: 24.70%

# %%
salaries_by_exp = df.groupby("experience_level")["salary_in_usd"].mean()
ex_se_diff = (salaries_by_exp.loc["Expert-level"] - salaries_by_exp.loc["Senior-level"]) 
se_mi_diff = (salaries_by_exp.loc["Senior-level"] - salaries_by_exp.loc["Mid-level"]) 
mi_en_diff = (salaries_by_exp.loc["Mid-level"] - salaries_by_exp.loc["Entry-level"]) 
print(f'Expert-Senior Difference: {int(ex_se_diff)} USD ({ex_se_diff / salaries_by_exp.loc["Senior-level"] * 100:.2f}%)')
print(f'Senior-Mid Difference: {int(se_mi_diff)} USD ({se_mi_diff / salaries_by_exp.loc["Mid-level"] * 100:.2f}%)')
print(f'Mid-Junior Difference: {int(mi_en_diff)} USD ({mi_en_diff / salaries_by_exp.loc["Entry-level"] * 100:.2f}%)')
# Out:
# Expert-Senior Difference: 60774 USD (43.84%)
# Senior-Mid Difference: 50621 USD (57.53%)
# Mid-Junior Difference: 26352 USD (42.75%)

# %% [markdown]
# Expert-Senior Difference: 60774 USD (43.84%)
#
# Senior-Mid Difference: 50621 USD (57.53%)
#
# Mid-Junior Difference: 26352 USD (42.75%)
#
# Salary and Experience level have a positive correlation. Which means, employees with higher experience get higher salaries.
#
# Salary increase between Mid-level and Entry-level positions are lowest by far (not in percentage).
#
# Possible Conclusion: If an employee gets more experienced, he/she will earn more money. Also, going from entry level to mid-level does not increase salary too much. But if an employee keeps working and becoming more experienced, the salary increase comes much more drastic. This also can be interpreted as, if you are a senior engineer, you can ask for a raise with more confidence because of the job market.

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))

sns.barplot(x='employment_type',y='salary_in_usd',data=df,estimator=mean)
ax.bar_label(ax.containers[0], label_type='edge', size=10, padding=1, fontname="Helvetica, Ariel", color="#7f7f7f")
plt.show()

# %% [markdown]
# Employees that work with a contract earn the most by far.
#
# Full-time employees are getting paid almost three times of what part-time employees are getting. Results are surprising for me because, full-time usually means working twice as much as part-time. That is why, I was expecting approximately a 100% difference, but here, we have a 243% difference.
#
# Possible Conclusion: Working with a contract is the best option by far because of the extremely high salaries. For the full-time/part-time difference, we may interpret this as, the companies does not value their part-time employees. Even though they are working 20hrs/wk (assumption), salaries are way lower than full-time, which is 40hrs/wk (assumption). Lastly, in this current job market, I think working full-time at a company is a better choice compared to working by him/herself as freelance.

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))

sns.barplot(x='job_title',y='salary_in_usd',order=df.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=True).index,data=df,estimator=mean)
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], label_type='edge', size=10, padding=1, fontname="Helvetica, Ariel", color="#7f7f7f")
plt.show()

# %% [markdown]
# By looking at this graph, I have some suspicions about the accuracy of the results. Some job titles such as Data Analytics Lead and Principal Data Engineer earning more than 3 million USD per year. Maybe there is insufficient data for some job titles. If only one entry is available with 3 million USD, this means the average is also 3 million, which does not really reflect reality. I will check if there are any job titles with single entry.

# %%
order1=df.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=True).index
order1
# Out:
# Index(['3D Computer Vision Researcher', 'Product Data Analyst', 'NLP Engineer',
#        'Computer Vision Engineer', 'Big Data Engineer', 'ETL Developer',
#        'Finance Data Analyst', 'Data Analytics Engineer', 'AI Scientist',
#        'Data Science Consultant', 'BI Data Analyst', 'Data Science Engineer',
#        'Business Data Analyst', 'Head of Machine Learning',
#        'Machine Learning Developer', 'Lead Machine Learning Engineer',
#        'Marketing Data Analyst', 'Lead Data Analyst', 'Data Analyst',
#        'Big Data Architect', 'Machine Learning Infrastructure Engineer',
#        'Machine Learning Engineer', 'Staff Data Scientist',
#        'Computer Vision Software Engineer', 'Data Scientist',
#        'Research Scientist', 'Data Engineer', 'Lead Data Scientist',
#        'Machine Learning Manager', 'ML Engineer', 'Principal Data Analyst',
#        'Data Engineering Manager', 'Cloud Data Engineer',
#        'Data Analytics Manager', 'Lead Data Engineer',
#        'Applied Machine Learning Scientist', 'Head of Data Science',
#        'Director of Data Engineering', 'Data Science Manager',
#        'Machine Learning Scientist', 'Head of Data', 'Data Specialist',
#        'Analytics Engineer', 'Applied Data Scientist', 'Data Architect',
#        'Director of Data Science', 'Principal Data Scientist',
#        'Financial Data Analyst', 'Principal Data Engineer',
#        'Data Analytics Lead'],
#       dtype='object', name='job_title')

# %%
data_1=df.groupby('job_title').agg('count')['work_year']
data_2=pd.DataFrame()
data_2['title']=data_1.index
data_2['count']=data_1.values

# %%
data_2[data_2['count']==1]
# Out:
#                              title  count
# 0    3D Computer Vision Researcher      1
# 6               Big Data Architect      1
# 14             Data Analytics Lead      1
# 23                 Data Specialist      1
# 27            Finance Data Analyst      1
# 31        Head of Machine Learning      1
# 35  Lead Machine Learning Engineer      1
# 40        Machine Learning Manager      1
# 42          Marketing Data Analyst      1
# 43                    NLP Engineer      1
# 49            Staff Data Scientist      1

# %%
salaries_mult_entry = df.groupby("job_title").filter(lambda x: len(x) > 1)
salaries_mult_entry
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020        Mid-level              FT
# 1             1       2020     Senior-level              FT
# 2             2       2020     Senior-level              FT
# 3             3       2020        Mid-level              FT
# 4             4       2020     Senior-level              FT
# ..          ...        ...              ...             ...
# 602         602       2022     Senior-level              FT
# 603         603       2022     Senior-level              FT
# 604         604       2022     Senior-level              FT
# 605         605       2022     Senior-level              FT
# 606         606       2022        Mid-level              FT
#
#                       job_title  salary_in_usd employee_residence  \
# 0                Data Scientist          79833                 DE
# 1    Machine Learning Scientist         260000                 JP
# 2             Big Data Engineer         109024                 GB
# 3          Product Data Analyst          20000                 HN
# 4     Machine Learning Engineer         150000                 US
# ..                          ...            ...                ...
# 602               Data Engineer         154000                 US
# 603               Data Engineer         126000                 US
# 604                Data Analyst         129000                 US
# 605                Data Analyst         150000                 US
# 606                AI Scientist         200000                 IN
#
#      remote_ratio company_location company_size
# 0               0               DE            L
# 1               0               JP            S
# 2              50               GB            M
# 3               0               HN            S
# 4              50               US            L
# ..            ...              ...          ...
# 602           100               US            M
# 603           100               US            M
# 604             0               US            M
# 605           100               US            M
# 606           100               US            L
#
# [596 rows x 10 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))

sns.barplot(x='job_title',y='salary_in_usd',order=salaries_mult_entry.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending=True).index,data=salaries_mult_entry,estimator=mean)
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], label_type='edge', size=10, padding=1, fontname="Helvetica, Ariel", color="#7f7f7f")
plt.show()

# %% [markdown]
# Principal Data Engineers and Financial Data Analysts are earning the most with over 2.5 million USD.
#
# Product Data Analysts are earning the least.
#
# I am still skeptical about these three titles. Two of them earning too much and one of them earning too little. I want to analyze them further.

# %%
data_2[data_2['title'].isin(['Financial Data Analyst','Principal Data Engineer'])]
df[df['job_title'].isin(['Financial Data Analyst','Principal Data Engineer'])]['company_location']
# Out:
# 97     US
# 121    US
# 215    US
# 252    US
# 461    US
# Name: company_location, dtype: object

# %%
df_1=df[df['company_location'].isin(['US','IN','HN'])]
df_1=pd.DataFrame(df_1)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 df_2
#
# NameError: name 'df_2' is not defined

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))

sns.barplot(x='company_location',y='salary_in_usd',data=df_1,estimator=mean)
ax.bar_label(ax.containers[0], label_type='edge', size=10, padding=1, fontname="Helvetica, Ariel", color="#7f7f7f")
plt.show()

# %% [markdown]
# I believe that my assumptions were correct. Average salary in US is significantly higher than, both India and Honduras combined. That also means, there is nothing wrong with the data.
#
# Possible Conclusion: Principal Data Engineer and Financial Data Analyst are earning the most. Product Data Analyst earning the least. But titles are correlated with countries as well. So, giving a definite opinion, just by looking at the job titles may not be a good idea.

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))

sns.barplot(x='employee_residence',y='salary_in_usd',order=df.groupby('employee_residence')['salary_in_usd'].mean().sort_values(ascending=True).index,data=df,estimator=mean)
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], label_type='edge', size=10, padding=1, fontname="Helvetica, Ariel", color="#7f7f7f")
plt.show()

# %%
data_3=pd.DataFrame()
data_3['empr']=df['employee_residence'].value_counts().index
data_3['emprcount']=df['employee_residence'].value_counts().values
data_3[data_3['emprcount']==1]
# Out:
#    empr  emprcount
# 29   BO          1
# 30   MY          1
# 31   TN          1
# 32   IE          1
# 33   DZ          1
# 34   AR          1
# 35   CZ          1
# 36   JE          1
# 37   LU          1
# 38   PR          1
# 39   RS          1
# 40   EE          1
# 41   CL          1
# 42   HK          1
# 43   KE          1
# 44   MD          1
# 45   CO          1
# 46   IR          1
# 47   CN          1
# 48   MT          1
# 49   UA          1
# 50   IQ          1
# 51   HN          1
# 52   BG          1
# 53   HR          1
# 54   PH          1
# 55   NZ          1
# 56   CH          1

# %%
salaries_mult_empl_entry = df.groupby("employee_residence").filter(lambda x: len(x) > 1)

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))

sns.barplot(x='employee_residence',y='salary_in_usd',order=salaries_mult_empl_entry.groupby('employee_residence')['salary_in_usd'].mean().sort_values(ascending=True).index,data=salaries_mult_empl_entry,estimator=mean)
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], label_type='edge', size=10, padding=1, fontname="Helvetica, Ariel", color="#7f7f7f")
plt.show()

# %% [markdown]
# Now it looks more realistic and reliable.
#
# Employees living in the US, earning the most with over 140k USD.
#
# Japan, United Arab Emirates, Canada, Russia, Singapore, and Australia are really close. Employees that are living in these countries earn slightly over 100k USD.
#
# Mexico and Turkey are the lowest ones with below 20k USD.
#
# Possible Conclusion: Salaries in the US are highest. This may be due to the fact that the number of big companies is way higher in the US than in any other country. Meanwhile, the lowest salaries are in Turkey and Mexico. This can be related to currency differences. Because we are analyzing salaries in USD.

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))

sns.barplot(x='remote_ratio',y='salary_in_usd',order=df.groupby('remote_ratio')['salary_in_usd'].mean().sort_values(ascending=True).index,data=df,estimator=mean)
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], label_type='edge', size=10, padding=1, fontname="Helvetica, Ariel", color="#7f7f7f")
plt.show()

# %% [markdown]
# Remote working employees earning the most.
#
# On-site work is more valuable than hybrid which is quite surprising to me.
#
# These results may be correlated with countries. As we learned previously, some countries like the US are providing higher salaries. I suspect that, maybe big portion of the remote workers are working for the US based companies. That's why, I will analyze these ratios with countries to prove my poin

# %%
full_remote_by_country = df[df["remote_ratio"] == 100]["company_location"].value_counts(ascending=False)
most_common_countries = list(full_remote_by_country.head(5).index)
remote_with_most_common_country = df[df["company_location"].isin(most_common_countries)]
remote_with_most_common_country=pd.DataFrame(remote_with_most_common_country)

# %%
sns.countplot(remote_with_most_common_country['remote_ratio'],hue=remote_with_most_common_country['company_location'])
# Out:
# C:\Users\Varun\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='remote_ratio', ylabel='count'>

# %% [markdown]
# It seems that my suspicions were correct. As we can see, most of the full-remote workers are working for US based companies.
#
# The US is giving the highest salaries in the world.
#
# This analysis also gives us an answer to "why, on-site employees are earning more than hybrid ones" question. US based on-site employees are more than US based hybrid employees.
#
# Possible Conclusion: Most of the people who want to pursue a remote career, chooses United States. Also in general, remote work pays the most. Hybrid may not be a good idea for this current job market.

# %%
plt.figure(figsize=(16,8))

sns.barplot(x='company_location',y='salary_in_usd',data=df,order=df.groupby('company_location')['salary_in_usd'].mean().sort_values(ascending=True).index,estimator=mean)
plt.xticks(rotation=90)
plt.show()

# %%
salaries_mult_comp_entry = df.groupby("company_location").filter(lambda x: len(x) > 2)

# %%
fig, ax = plt.subplots(1, 1, figsize=(20, 7))

sns.barplot(x='company_location',y='salary_in_usd',order=salaries_mult_comp_entry.groupby('company_location')['salary_in_usd'].mean().sort_values(ascending=True).index,data=salaries_mult_comp_entry,estimator=mean)
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], label_type='edge', size=10, padding=1, fontname="Helvetica, Ariel", color="#7f7f7f")
plt.show()

# %% [markdown]
# The US takes first place with a salary of more than 140k USD. The graph is very similar to Employee Residence.
#
# Possible Conclusion: Companies based in the United States pay the highest wages. Japan, Canada, Australia, and United Arab
# Emirates are really close to each other. These results may be correlated with the countries' currencies.

# %%
plt.figure(figsize=(16,8))

sns.barplot(x='company_size',y='salary_in_usd',data=df,order=df.groupby('company_size')['salary_in_usd'].mean().sort_values(ascending=True).index,estimator=mean)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Large and mid-size companies are almost equal in terms of salaries.
#
# When compared to small-size companies, large/mid-size companies pay approximately 51.73% more.
#
# Possible Conclusion: Large and mid-size companies pay about the same. Meanwhile, small companies are giving way less. I assume
# that, small companies have less money; therefore, they can't give too much money to their employees.

# %% [markdown]
# FINAL CONCLUSION
#
#
# Data science jobs are getting more popular.
#
# If an employee wants to get the highest salary possible, United States should be their choice. But of course, this analysis is purely based on the salaries. To give an answer to this, we should also analyze the cost of living, health-care, etc.
#
# Large and mid-size companies are providing more salaries compared to small ones.
#
# Remote jobs are more popular and also pay the most. This may be due to the pandemic.
#
# Salary increase becomes drastic once you have gained a senior-level experience.
#
# Contract and full-time employments are way to go for 2022.
#
# Data Engineers, Data Scientists, and Machine Learning Engineers are the most valuable titles (by looking at their average
# salary).
#
# The majority of the data is based in the United States. Since the United States pays much higher wages than other countries, I don't believe these average salaries reflect reality. As a result, I would not base my expectations by looking at these average salaries.
#
# After conducting this analysis, I believe that pursuing a data science related job is a good career choice in terms of salary and remote options.
